# %%
import requests
import json
import pandas as pd

# %%
API_key = "1fd00ba235bf47278e2c13643565a3ce"

# %%
#1-й запрос
import requests
url = ('https://newsapi.org/v2/everything?''q=Apple&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()

# %%
res.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
res['articles'][0].keys()
# Out:
# dict_keys(['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

# %%
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)
news_df
# Out:
#                                       source         author  \
# 0   {'id': 'the-verge', 'name': 'The Verge'}    Verge Staff
# 1   {'id': 'the-verge', 'name': 'The Verge'}    Jason Snell
# 2   {'id': 'the-verge', 'name': 'The Verge'}      Emma Roth
# 3           {'id': 'wired', 'name': 'Wired'}  Noam Scheiber
# 4   {'id': 'the-verge', 'name': 'The Verge'}   John.Higgins
# ..                                       ...            ...
# 64         {'id': None, 'name': 'MacRumors'}    Juli Clover
# 65          {'id': 'wired', 'name': 'Wired'}   Nena Farrell
# 66       {'id': None, 'name': 'Gizmodo.com'}      Kyle Barr
# 67         {'id': None, 'name': 'MacRumors'}  Joe Rossignol
# 68         {'id': None, 'name': 'MacRumors'}    Juli Clover
#
#                                                 title  \
# 0                     Rank the 50 best Apple products
# 1                                        Between Jobs
# 2   Apple could put ads in Maps as soon as this su...
# 3   How the Vision Pro Rollout Inflamed Tensions a...
# 4   Apple Studio Display XDR review: pro at a premium
# ..                                                ...
# 64  Apple Adds 'Genius Browse' Movie and TV Recomm...
# 65  Ikea’s New Lineup of Smart Home Gear Is Quietl...
# 66  There’s a Good Reason the MacBook Neo Is Apple...
# 67   No Major Apple Watch Redesign Expected This Year
# 68  Apple Can Create Smaller On-Device AI Models F...
#
#                                           description  \
# 0   In honor of Apple’s 50th anniversary, The Verg...
# 1   This is part of our package about Apple's 50th...
# 2   Apple will soon bring advertisements to its Ma...
# 3   Even before the headset’s release, the workfor...
# 4   It's been almost exactly four years since Appl...
# ..                                                ...
# 64  tvOS 26.4 includes a new Genius Browse section...
# 65  Ikea’s latest light bulbs, remotes, and more h...
# 66  Apple's $600 MacBook Neo finally eschews glue ...
# 67  In addition to indicating that a new full-size...
# 68  Apple has full access to Gemini to customize t...
#
#                                                   url           publishedAt  \
# 0   https://www.theverge.com/cs/tech/900477/apple-...  2026-03-27T10:00:00Z
# 1   https://www.theverge.com/tech/897520/apple-wit...  2026-03-30T17:57:09Z
# 2   https://www.theverge.com/tech/899053/apple-map...  2026-03-23T18:54:44Z
# 3   https://www.wired.com/story/book-excerpt-mutin...  2026-04-07T10:00:00Z
# 4   https://www.theverge.com/tech/891436/apple-stu...  2026-03-09T19:53:45Z
# ..                                                ...                   ...
# 64  https://www.macrumors.com/2026/03/18/tvos-26-4...  2026-03-18T23:17:12Z
# 65  https://www.wired.com/story/ikea-matter-smart-...  2026-04-08T13:16:00Z
# 66  https://gizmodo.com/theres-a-good-reason-the-m...  2026-03-16T16:10:24Z
# 67  https://www.macrumors.com/2026/03/26/no-major-...  2026-03-26T18:12:55Z
# 68  https://www.macrumors.com/2026/03/25/apple-goo...  2026-03-25T16:53:40Z
#
#                                               content
# 0   For any one person, ranking 50 items can be a ...
# 1   <ul><li></li><li></li></ul>\r\nWith Steve Jobs...
# 2   <ul><li></li><li></li><li></li></ul>\r\nThe ro...
# 3   To roll out its new mixed-reality headset, the...
# 4   <ul><li></li><li></li><li></li></ul>\r\nProfes...
# ..                                                ...
# 64  tvOS 26.4 includes a new Genius Browse section...
# 65  I've always been an Ikea fan. I lived in nine ...
# 66  The MacBook Neo took the scene last week as Ap...
# 67  In addition to indicating that a new full-size...
# 68  Apple has full access to Gemini to customize t...
#
# [69 rows x 7 columns]

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2026.2.25)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
df = news_df
analyzer = SentimentIntensityAnalyzer()

# %%
def get_vader_sentiment(text):
    if pd.isna(text) or text == "None":
        return None
    return analyzer.polarity_scores(str(text))['compound']

df['content_sentiment'] = df['content'].apply(get_vader_sentiment)

print(df[['title','content_sentiment']])
# Out:
#                                                 title  content_sentiment
# 0                     Rank the 50 best Apple products             0.4215
# 1                                        Between Jobs            -0.1585
# 2   Apple could put ads in Maps as soon as this su...             0.5574
# 3   How the Vision Pro Rollout Inflamed Tensions a...             0.3230
# 4   Apple Studio Display XDR review: pro at a premium             0.7543
# ..                                                ...                ...
# 64  Apple Adds 'Genius Browse' Movie and TV Recomm...             0.0000
# 65  Ikea’s New Lineup of Smart Home Gear Is Quietl...             0.1655
# 66  There’s a Good Reason the MacBook Neo Is Apple...             0.4927
# 67   No Major Apple Watch Redesign Expected This Year             0.0000
# 68  Apple Can Create Smaller On-Device AI Models F...             0.0000
#
# [69 rows x 2 columns]

# %%
df['content_sentiment'].mean()
# Out:
# np.float64(0.22098695652173914)

# %% [markdown]
# Какой вывод можно сделать?
#
# Сегодня сентимент для Apple 0.22, что является положительным, но не сильно. Варимция у нас от [-1 до 1]

# %%
#2-й запрос
import requests
url = ('https://newsapi.org/v2/top-headlines?''category=business&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)

# %%
def clean_page_columns(news_df):
    news_df['source'] = news_df['source'].apply(lambda d: d['name'])
    return news_df[['source', 'author', 'title', 'description', 'url', 'publishedAt', 'content']]
page = pd.DataFrame(res['articles'])
news_df_cleaned = clean_page_columns(page)
news_df_cleaned
# Out:
#                  source                                  author  \
# 0              Barron's        Nicole Goodkind, Megan Leonhardt
# 1   Yahoo Entertainment                      Hal Bundrick, CFP®
# 2                  CNBC            Sean Conlon, Lisa Kailai Han
# 3        The Points Guy                             Sean Cudahy
# 4                  CNBC                         Michael Wayland
# 5                  CNBC           Lillian Rizzo, Julia Boorstin
# 9   https://www.politico.eu/article/eu-supports-st...  2026-04-09T13:36:00Z
# 10  https://www.bloomberg.com/news/articles/2026-0...  2026-04-09T13:10:53Z
# 11  https://www.intc.com/news-events/press-release...  2026-04-09T13:03:49Z
# 12  https://newsroom.servicenow.com/press-releases...  2026-04-09T13:02:49Z
# 13  https://people.com/man-races-home-tell-wife-he...  2026-04-09T12:32:00Z
# 14  https://www.bea.gov/news/2026/personal-income-...  2026-04-09T12:30:00Z
# 15  https://www.cnbc.com/2026/04/09/family-offices...  2026-04-09T11:45:10Z
# 16  https://coreweave.com/news/coreweave-and-meta-...  2026-04-09T11:07:50Z
#
#                                               content
# 0   The Bureau of Economic Analysis released the F...
# 1   Mortgage rates fell for the first time in over...
# 2   Stocks rose for a second day on Thursday, even...
# 3   American Airlines is raising its checked bag f...
# 4   Kia plans to release a pickup truck for Americ...
# 5   Disney is planning to begin its next phase of ...
# 6   WASHINGTON (AP) The American economy, slowed b...
# 7   Amazon CEO Andy Jassy’s annual shareholder let...
# 8   Analysts Disclosure: I/we have no stock, optio...
# 9   These and 40 other unnamed organizations have ...
# 10  Oil edged higher in choppy trading as investor...
# 11  NEWS HIGHLIGHTS:\r\n<ul><li>\r\nIntel® Xeon® p...
# 12  SANTA CLARA, Calif.--(BUSINESS WIRE)-- Service...
# 13  NEED TO KNOW\r\n<ul><li>James Milby won six-fi...
# 14  Personal income decreased $18.2 billion (0.1 p...
# 15  A version of this article first appeared in CN...
# 16  Livingston, NJ April 9, 2026 CoreWeave (Nasdaq...

# %%
def get_vader_sentiment(text):
    if pd.isna(text) or text == "None":
        return None
    return analyzer.polarity_scores(str(text))['compound']

news_df_cleaned['content_sentiment'] = news_df_cleaned['content'].apply(get_vader_sentiment)

print(news_df_cleaned[['title','content_sentiment']])
# Out:
#                                                 title  content_sentiment
# 0   PCE Inflation Report: What February Core, Head...            -0.2280
# 1   Mortgage rates fall on Iran ceasefire: Mortgag...             0.4767
# 2   Stocks gain for a second day on hope Iran ceas...             0.7269
# 3   American Airlines hikes bag fees, adds tough n...             0.1036
# 4   Kia plans to launch U.S. pickup truck by 2030 ...            -0.3818
# 5   Disney plans layoffs of as many as 1,000 emplo...            -0.1027
# 6   US economy grew a sluggish 0.5% in fourth quar...            -0.4019
# 7   Amazon CEO takes aim at Nvidia, Intel, Starlin...             0.7650
# 8   Palantir: This Could End Badly (NASDAQ:PLTR) -...            -0.5267
# 9   EU welcomes Anthropic’s move to slow the relea...             0.1280
# 10  Oil Rises After Biggest Drop Since 2020 as Hor...            -0.2732
# 11  Intel and Google Deepen Collaboration to Advan...             0.0000
# 12  ServiceNow moves beyond the sidecar AI era, gi...             0.0000
# 13  Man Races Home to Tell Wife He Won $551K Lotte...             0.9042
# 14  Personal Income and Outlays, February 2026 - U...             0.0000
# 15  Family offices piled into oil after capital dr...             0.4939
# 16  CoreWeave and Meta Expand $21B AI Cloud Deal -...             0.4939

# %%
news_df_cleaned['content_sentiment'].mean()
# Out:
# np.float64(0.12811176470588237)

# %% [markdown]
# Тут у нас он получился меньше чем в прошлый раз, тут мы собирали просто новости по всему бизнесу в целом.

# %%
#3-й запрос
import requests
url = ('https://newsapi.org/v2/top-headlines?''country=us&''category=business&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)

# %%
def clean_page_columns(news_df):
    news_df['source'] = news_df['source'].apply(lambda d: d['name'])
    return news_df[['source', 'author', 'title', 'description', 'url', 'publishedAt', 'content']]

# %%
page = pd.DataFrame(res['articles'])
news_df_cleaned = clean_page_columns(page)
news_df_cleaned
# Out:
#                  source                                  author  \
# 0              Barron's        Nicole Goodkind, Megan Leonhardt
# 1   Yahoo Entertainment                      Hal Bundrick, CFP®
# 2                  CNBC            Sean Conlon, Lisa Kailai Han
# 3        The Points Guy                             Sean Cudahy
# 4                  CNBC                         Michael Wayland
# 5                  CNBC           Lillian Rizzo, Julia Boorstin
# 6      Associated Press                            Paul Wiseman
# 7            TechCrunch                              Julie Bort
# 8         Seeking Alpha                    Bears of Wall Street
# 9           POLITICO.eu                            Pieter Haeck
# 10            Bloomberg  Rong Wei Neo, Alex Longley, Mia Gindis
# 11             Intc.com                                    None
# 12       Servicenow.com                                    None
# 13               PEOPLE                           Paloma Chavez
# 14              Bea.gov                                    None
# 15                 CNBC                       Hayley Cuccinello
# 16        Coreweave.com                                    None
#
#                                                 title  \
# 0   PCE Inflation Report: What February Core, Head...
# 1   Mortgage rates fall on Iran ceasefire: Mortgag...
# 2   Stocks gain for a second day on hope Iran ceas...
# 3   American Airlines hikes bag fees, adds tough n...
# 4   Kia plans to launch U.S. pickup truck by 2030 ...
# 5   Disney plans layoffs of as many as 1,000 emplo...
# 6   US economy grew a sluggish 0.5% in fourth quar...
# 7   Amazon CEO takes aim at Nvidia, Intel, Starlin...
# 8   Palantir: This Could End Badly (NASDAQ:PLTR) -...
# 9   EU welcomes Anthropic’s move to slow the relea...
# 10  Oil Rises After Biggest Drop Since 2020 as Hor...
# 11  Intel and Google Deepen Collaboration to Advan...
# 12  ServiceNow moves beyond the sidecar AI era, gi...
# 13  Man Races Home to Tell Wife He Won $551K Lotte...
# 14  Personal Income and Outlays, February 2026 - U...
# 15  Family offices piled into oil after capital dr...
# 16  CoreWeave and Meta Expand $21B AI Cloud Deal -...
#
#                                           description  \
# 0   The February personal consumption expenditures...
# 1   Mortgage rates fall for the first time in over...
# 2   The S&P 500 moved into positive territory on T...
# 3   American Airlines became the latest to hike ch...
# 4   Kia plans to release a pickup truck for Americ...
# 5   Disney is planning a new phase of cost cutting...
# 6   The American economy, slowed by last fall’s 43...
# 7   Andy Jassy's annual shareholder letter reads s...
# 8   Palantir faces heightened risk from AI agent d...
# 9   The tech company made the announcement after f...
# 10  Oil edged higher in choppy trading as investor...
# 11                                               None
# 12  New Context Engine provides the enterprise con...
# 2   Stocks gain for a second day on hope Iran ceas...             0.7269
# 3   American Airlines hikes bag fees, adds tough n...             0.1036
# 4   Kia plans to launch U.S. pickup truck by 2030 ...            -0.3818
# 5   Disney plans layoffs of as many as 1,000 emplo...            -0.1027
# 6   US economy grew a sluggish 0.5% in fourth quar...            -0.4019
# 7   Amazon CEO takes aim at Nvidia, Intel, Starlin...             0.7650
# 8   Palantir: This Could End Badly (NASDAQ:PLTR) -...            -0.5267
# 9   EU welcomes Anthropic’s move to slow the relea...             0.1280
# 10  Oil Rises After Biggest Drop Since 2020 as Hor...            -0.2732
# 11  Intel and Google Deepen Collaboration to Advan...             0.0000
# 12  ServiceNow moves beyond the sidecar AI era, gi...             0.0000
# 13  Man Races Home to Tell Wife He Won $551K Lotte...             0.9042
# 14  Personal Income and Outlays, February 2026 - U...             0.0000
# 15  Family offices piled into oil after capital dr...             0.4939
# 16  CoreWeave and Meta Expand $21B AI Cloud Deal -...             0.4939

# %%
#4-й запрос
import requests
url = ('https://newsapi.org/v2/everything?''q=bitcoin&''sortBy=popularity&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)
def clean_page_columns(news_df):
    news_df['source'] = news_df['source'].apply(lambda d: d['name'])
    return news_df[['source', 'author', 'title', 'description', 'url', 'publishedAt', 'content']]
page = pd.DataFrame(res['articles'])
news_df_cleaned = clean_page_columns(page)
news_df_cleaned
# Out:
#             source                                    author  \
# 0            Wired                               Kate Knibbs
# 1            Wired                          Matthew S. Smith
# 2      Gizmodo.com                               Kyle Torpey
# 3      Gizmodo.com                                 Bruce Gil
# 4      Gizmodo.com                               Kyle Torpey
# ..             ...                                       ...
# 95    Techmeme.com                                      None
# 96    Techmeme.com                                      None
# 97  Les Numériques                          Mathilde DOUSSET
# 98  Les Numériques                          Juliette Sbranna
# 99        Internet  info@thehackernews.com (The Hacker News)
#
#                                                 title  \
# 0   Wall Street Is Already Betting on Prediction M...
# 1   Identity Theft Protection Services: Do You Act...
# 2   UK Man Accuses Spouse of Stealing $172 Million...
# 3   The New York Times Claims It Finally Unmasked ...
# 4   Gemini, Crypto.com Latest Crypto Firms to Blam...
# ..                                                ...
# 95  Fannie Mae will accept crypto-backed mortgages...
# 96  A look at Coinbase One and other insurance-lik...
# 97  Acheter du Bitcoin quand son prix baisse : opp...
# 98  Actualité : X Money : la néobanque d’Elon Musk...
# 99  ⚡ Weekly Recap: Axios Hack, Chrome 0-Day, Fort...
#
#                                           description  \
# 0   As the legal war over how to regulate predicti...
# 1   Here's the best advice I have for protecting y...
# 2   Code is law, some say. That doesn't mean norma...
# 3   If true, the man would be one of the richest p...
# 4   Meanwhile, some companies have abandoned crypt...
# ..                                                ...
# 95  Wall Street Journal:\nFannie Mae will accept c...
# 96  Bloomberg:\nA look at Coinbase One and other i...
# 97  Le Bitcoin est connu pour sa volatilité. En qu...
# 98  Elon Musk prépare le lancement de X Money, sa ...
# 99  This week had real hits. The key software got ...
#
#                                                   url           publishedAt  \
# 0   https://www.wired.com/story/prediction-markets...  2026-03-16T09:30:00Z
# 1   https://www.wired.com/story/best-id-protection...  2026-03-14T10:30:00Z
# 2   https://gizmodo.com/uk-man-accuses-spouse-of-s...  2026-03-17T22:47:01Z
# 3   https://gizmodo.com/the-new-york-times-claims-...  2026-04-08T16:40:08Z
# 4   https://gizmodo.com/gemini-crypto-com-latest-c...  2026-03-21T17:00:54Z
# ..                                                ...                   ...
# 95                https://www.techmeme.com/260326/p35  2026-03-26T18:40:00Z
# 96                 https://www.techmeme.com/260329/p8  2026-03-29T19:40:14Z
# 97  https://www.lesnumeriques.com/societe-numeriqu...  2026-04-07T07:00:00Z
# 98  https://www.lesnumeriques.com/societe-numeriqu...  2026-03-11T19:45:00Z
# 99  https://thehackernews.com/2026/04/weekly-recap...  2026-04-06T12:46:00Z
#
#                                               content
# 0   When Troy Dixon first suggested incorporating ...
# 1   Odds are good youve encountered an identity th...
# 2   Ping Fai Yuen, who is a U.K. resident, has acc...
# 3   The real identity of Satoshi Nakamoto, the cre...
# 4   With the bitcoin price still sitting roughly 4...
# ..                                                ...
# 95  About This Page\r\nThis is a Techmeme archive ...
# 96  About This Page\r\nThis is a Techmeme archive ...
# 97  Le Bitcoin est connu pour sa volatilité. En qu...
# 98  Elon Musk lance sa neobanque ; X Money\r\n© Sh...
# 99  This week had real hits. The key software got ...
#
# [100 rows x 7 columns]

# %%
news_df_cleaned['content_sentiment'] = news_df_cleaned['content'].apply(get_vader_sentiment)

print(news_df_cleaned[['title','content_sentiment']])
# Out:
#                                                 title  content_sentiment
# 0   Wall Street Is Already Betting on Prediction M...            -0.3400
# 1   Identity Theft Protection Services: Do You Act...             0.4404
# 2   UK Man Accuses Spouse of Stealing $172 Million...            -0.6124
# 3   The New York Times Claims It Finally Unmasked ...             0.1280
# 4   Gemini, Crypto.com Latest Crypto Firms to Blam...            -0.2263
# ..                                                ...                ...
# 95  Fannie Mae will accept crypto-backed mortgages...             0.0000
# 96  A look at Coinbase One and other insurance-lik...             0.0000
# 97  Acheter du Bitcoin quand son prix baisse : opp...             0.0000
# 98  Actualité : X Money : la néobanque d’Elon Musk...             0.0000
# 99  ⚡ Weekly Recap: Axios Hack, Chrome 0-Day, Fort...            -0.0516
#
# [100 rows x 2 columns]

# %%
news_df_cleaned['content_sentiment'].mean()
# Out:
# np.float64(0.018052000000000002)

# %% [markdown]
# В новостях про биткоин выявить тенденции не удалось.

# %%
#5-й запрос
import requests
url = ('https://newsapi.org/v2/everything?''q=finance&''sortBy=popularity&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)
def clean_page_columns(news_df):
    news_df['source'] = news_df['source'].apply(lambda d: d['name'])
# 97  Stocks closed higher on Monday, recovering fro...
# 98  The Trump administration is expected to send t...
#
# [99 rows x 7 columns]

# %%
news_df_cleaned['content_sentiment'] = news_df_cleaned['content'].apply(get_vader_sentiment)

print(news_df_cleaned[['title','content_sentiment']])
# Out:
#                                                 title  content_sentiment
# 0   Wall Street Is Already Betting on Prediction M...            -0.3400
# 1   AI Czar David Sacks wants Trump to ‘get out’ o...            -0.9325
# 2   Oh, you think the government will regulate Kal...             0.1306
# 3                                   You Could Be Next            -0.5927
# 4   Survival or FA Cup glory - which would you cho...             0.8860
# ..                                                ...                ...
# 94  Irán se fijó como objetivo acabar con Dubái: l...            -0.2960
# 95  Yuanjie es la desconocida empresa china de tec...            -0.2960
# 96  Create Dangerously: Albert Camus on the Power ...             0.6115
# 97  Stocks close higher, reversing sharp losses af...            -0.7650
# 98  Treasury taking over federal student loans ami...             0.2023
#
# [99 rows x 2 columns]

# %%
news_df_cleaned['content_sentiment'].mean()
# Out:
# np.float64(0.02403434343434344)

# %% [markdown]
# Тут мы опять получили нулевой сентимент.

# %%
#6-й запрос
import requests
url = ('https://newsapi.org/v2/everything?''q=акции&''language=ru&''sortBy=popularity&''apiKey=1fd00ba235bf47278e2c13643565a3ce')
response = requests.get(url)
res = response.json()
news_df = pd.DataFrame(res['articles'])
news_df = news_df.drop('urlToImage', axis=1)
def clean_page_columns(news_df):
    news_df['source'] = news_df['source'].apply(lambda d: d['name'])
    return news_df[['source', 'author', 'title', 'description', 'url', 'publishedAt', 'content']]
page = pd.DataFrame(res['articles'])
news_df_cleaned = clean_page_columns(page)
news_df_cleaned
# Out:
#            source                            author  \
# 0        Habr.com              klimensky (FirstVDS)
# 1   Lifehacker.ru                       Мила Цимбал
# 2           Lenta                      Кирилл Луцюк
# 3           Lenta                Лилиана Набиуллина
# 4           Lenta                    Алена Шевченко
# ..            ...                               ...
# 95       BBC News  https://www.facebook.com/bbcnews
# 96       BBC News                              None
# 97       BBC News                              None
# 98    Interfax.ru                              None
# 99    Interfax.ru                              None
#
#                                                 title  \
# 0   Как Apple едва не уничтожила себя, разрешив кл...
# 1   «Великая китайская распродажа» на AliExpress: ...
# 2   Война с Ираном обрушила акции европейских комп...
# 3   Акции Сбера ускорили рост после слов Грефа о п...
# 4   Россиянам развеяли два популярных мифа об орга...
# ..                                                ...
# 95  В США проходят акции протеста против Дональда ...
# 96        Как война в Иране бьет по рейтингам Трампа?
# 97  Митинги в защиту «Телеграма»: протест или пров...
# 98  Суд присудил Газпрому акции ликвидированных юр...
# 99  Производитель игрушек Labubu в 2025 году нарас...
#
#                                           description  \
# 0   В 1997 году акции Apple стоили 4 доллара. Комп...
# 1   Изучили ассортимент и собрали товары, на котор...
# 2   Ближневосточный кризис нанес еще один удар по ...
# 3   Акции Сбера отреагировали ростом на заявление ...
# 4   Качественное органическое вино не имеет дрожже...
# ..                                                ...
# 95  В городах по всей территории США проходят масш...
# 96  В этом выпуске поговорим о том, как война в Ир...
# 97  На 29 марта в России анонсированы протесты про...
# 98  Интерфакс: "Газпром" в суде оформил собственно...
# 99  Интерфакс: Акции компании падают на 21,5% на ф...
#
#                                                   url           publishedAt  \
# 0   https://habr.com/ru/companies/first/articles/1...  2026-03-20T09:40:54Z
# 1                https://lifehacker.ru/vkr-mart-2026/  2026-03-13T11:00:00Z
# 2   https://lenta.ru/news/2026/04/07/voyna-s-irano...  2026-04-07T12:36:19Z
# 3   https://lenta.ru/news/2026/03/17/aktsii-sbera-...  2026-03-17T13:00:52Z
# 4   https://lenta.ru/news/2026/04/05/rossiyanam-ra...  2026-04-05T04:30:54Z
# ..                                                ...                   ...
# 95  https://www.bbc.com/russian/articles/cde5lpde4pko  2026-03-29T07:16:19Z
# 96  https://www.bbc.com/russian/podcasts/p076qqzl/...  2026-03-31T00:00:00Z
# 97  https://www.bbc.com/russian/podcasts/p076qqzl/...  2026-03-26T14:33:00Z
# 98           https://www.interfax.ru/business/1078081  2026-03-16T04:12:00Z
# 99           https://www.interfax.ru/business/1079854  2026-03-25T07:29:00Z
#
#                                               content
# 0   Apple : . , , .\r\n 1994 Apple . Mac «» .\r\n ...
# 1   : 16 «» AliExpress. , , , , 90%. , : .\r\n , -...
# 2   . Bloomberg.\r\n, Euro Stoxx 50, 50 12 , . S&a...
# 3   «» , . 15:10 0,82 , 318,98 , Investing.com.\r\...
# 4   , ,  . «.» « ».\r\n , . , , , , , .\r\n« , , ....
# ..                                                ...
# 95  , : « »\r\n« ». , . \r\n , , , , .\r\n« . , , ...
# 96  , . . « !». , .\r\n .\r\n00:00 . \r\n00:44 ?\r...
# 97  29 . , . , . 1 «». ? ? «» ? -- .\r\n00:00 . \r...
# 98  . 16 . INTERFAX.RU - "" 342 . - . , 2024-2025 ...
# 99  21,5% \r\n. 25 . INTERFAX.RU - Pop Mart Intern...
#
# [100 rows x 7 columns]

# %%
news_df_cleaned['content_sentiment'] = news_df_cleaned['content'].apply(get_vader_sentiment)

print(news_df_cleaned[['title','content_sentiment']])
# Out:
#                                                 title  content_sentiment
# 0   Как Apple едва не уничтожила себя, разрешив кл...                0.0
# 1   «Великая китайская распродажа» на AliExpress: ...                0.0
# 2   Война с Ираном обрушила акции европейских комп...                0.0
# 3   Акции Сбера ускорили рост после слов Грефа о п...                0.0
# 4   Россиянам развеяли два популярных мифа об орга...                0.0
# ..                                                ...                ...
# 95  В США проходят акции протеста против Дональда ...                0.0
# 96        Как война в Иране бьет по рейтингам Трампа?                0.0
# 97  Митинги в защиту «Телеграма»: протест или пров...                0.0
# 98  Суд присудил Газпрому акции ликвидированных юр...                0.0
# 99  Производитель игрушек Labubu в 2025 году нарас...                0.0
#
# [100 rows x 2 columns]

# %% [markdown]
# А на русскоязычных данных он не работает.

# %% [markdown]
# Что мы получили по итогу, сентимент мы оценивать можем только для english, следующая итерация. Мы хотим проверить как влияет и влияет ли сентимент на изменение цены акции, для более эффективной торговли.
